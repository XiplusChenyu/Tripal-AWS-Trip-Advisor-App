# %%
import requests
import json

API_KEY = "AIzaSyAx_aaPjCjgx6wzc3BOlK55Qp1OoHFA5bA"

placeid = 'ChIJoxqn-kD2wokRLvhOLfAneU8'


# https://maps.googleapis.com/maps/api/place/details/json?placeid=ChIJ9U1mz_5YwokRosza1aAk0jM
#     &fields=name,rating,price_level,website,opening_hours,formatted_phone_number,review
#     &key=AIzaSyAx_aaPjCjgx6wzc3BOlK55Qp1OoHFA5bA



link =  "https://maps.googleapis.com/maps/api/place/details/json?placeid="

link += placeid + '&fields=name,rating,price_level,website,opening_hours,formatted_phone_number,review'+'&key=' +API_KEY


# temp = ('+'.join(city.upper().split(' ')))
# link +=  temp + '+point+of+interest&language=en&key=' + API_KEY
r = requests.get(link)
temp = json.loads(r.text)

# %%
print(json.dumps(temp,indent = 2))
# Out:
# {
#   "html_attributions": [],
#   "result": {
#     "formatted_phone_number": "(212) 666-1640",
#     "name": "General Grant National Memorial",
#     "opening_hours": {
#       "open_now": true,
#       "periods": [
#         {
#           "close": {
#             "day": 0,
#             "time": "1100"
#           },
#           "open": {
#             "day": 0,
#             "time": "1000"
#           }
#         },
#         {
#           "close": {
#             "day": 0,
#             "time": "1300"
#           },
#           "open": {
#             "day": 0,
#             "time": "1200"
#           }
#         },
#         {
#           "close": {
#             "day": 0,
#             "time": "1500"
#           },
#           "open": {
#             "day": 0,
#             "time": "1400"
#           }
#         },
#         {
#           "close": {
#             "day": 0,
#             "time": "1700"
#           },
#           "open": {
#             "day": 0,
#             "time": "1600"
#           }
#         },
#         {
#           "close": {
#             "day": 3,
#             "time": "1100"
#           },
#           "open": {
#             "day": 3,
#             "time": "1000"
#           }
#         },
#         {
#           "close": {
#             "day": 3,
#             "time": "1300"
#           },
#           "open": {
#             "day": 3,
#             "time": "1200"
#           }
#         },
#         {
#           "close": {
#             "day": 3,
#             "time": "1500"
#           },
#           "open": {
#             "day": 3,
#             "time": "1400"
#           }
#         },
#         {
#           "close": {
#             "day": 3,
#             "time": "1700"
#           },
#           "open": {
#             "day": 3,
#             "time": "1600"
#           }
#         },
#         {
#           "close": {
#             "day": 4,
#             "time": "1100"
#           },
#           "open": {
#             "day": 4,
#             "time": "1000"
#           }
#         },
#         {
#           "close": {
#             "day": 4,
#             "time": "1300"
#           },
#           "open": {
#             "day": 4,
#             "time": "1200"
#           }
#         },
#         {
#           "close": {
#             "day": 4,
#             "time": "1500"
#           },
#           "open": {
#             "day": 4,
#             "time": "1400"
#           }
#         },
#         {
#           "close": {
#             "day": 4,
#             "time": "1700"
#           },
#           "open": {
#             "day": 4,
#             "time": "1600"
#           }
#         },
#         {
#           "close": {
#             "day": 5,
#             "time": "1100"
#           },
#           "open": {
#             "day": 5,
#             "time": "1000"
#           }
#         },
#         {
#           "close": {
#             "day": 5,
#             "time": "1300"
#           },
#           "open": {
#             "day": 5,
#             "time": "1200"
#           }
#         },
#         {
#           "close": {
#             "day": 5,
#             "time": "1500"
#           },
#           "open": {
#             "day": 5,
#             "time": "1400"
#           }
#         },
#         {
#           "close": {
#             "day": 5,
#             "time": "1700"
#           },
#           "open": {
#             "day": 5,
#             "time": "1600"
#           }
#         },
#         {
#           "close": {
#             "day": 6,
#             "time": "1100"
#           },
#           "open": {
#             "day": 6,
#             "time": "1000"
#           }
#         },
#         {
#           "close": {
#             "day": 6,
#             "time": "1300"
#           },
#           "open": {
#             "day": 6,
#             "time": "1200"
#           }
#         },
#         {
#           "close": {
#             "day": 6,
#             "time": "1500"
#           },
#           "open": {
#             "day": 6,
#             "time": "1400"
#           }
#         },
#         {
#           "close": {
#             "day": 6,
#             "time": "1700"
#           },
#           "open": {
#             "day": 6,
#             "time": "1600"
#           }
#         }
#       ],
#       "weekday_text": [
#         "Monday: Closed",
#         "Tuesday: Closed",
#         "Wednesday: 10:00 \u2013 11:00 AM, 12:00 \u2013 1:00 PM, 2:00 \u2013 3:00 PM, 4:00 \u2013 5:00 PM",
#         "Thursday: 10:00 \u2013 11:00 AM, 12:00 \u2013 1:00 PM, 2:00 \u2013 3:00 PM, 4:00 \u2013 5:00 PM",
#         "Friday: 10:00 \u2013 11:00 AM, 12:00 \u2013 1:00 PM, 2:00 \u2013 3:00 PM, 4:00 \u2013 5:00 PM",
#         "Saturday: 10:00 \u2013 11:00 AM, 12:00 \u2013 1:00 PM, 2:00 \u2013 3:00 PM, 4:00 \u2013 5:00 PM",
#         "Sunday: 10:00 \u2013 11:00 AM, 12:00 \u2013 1:00 PM, 2:00 \u2013 3:00 PM, 4:00 \u2013 5:00 PM"
#       ]
#     },
#     "price_level": 0,
#     "rating": 4.5,
#     "reviews": [
#       {
#         "author_name": "Steven Scalici",
#         "author_url": "https://www.google.com/maps/contrib/104817268573065119850/reviews",
#         "language": "en",
#         "profile_photo_url": "https://lh3.googleusercontent.com/-XnmG8hh3RhA/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3reoSlPcXSgs3ZR2n4Xhj4-YDyXJOQ/s128-c0x00000000-cc-rp-mo-ba4/photo.jpg",
#         "rating": 5,
#         "relative_time_description": "a month ago",
#         "text": "One of my favorite places in all of Manhattan, perhaps because it is quiet and forgotten, or it is across the street from Riverside Church (beautiful in its own right), or maybe because the leading plaza is so peaceful.  Or that it is an easily accessible National Monument from the 1 train subway one block away.  Orrrr, it lies along Riverside Drive, a beautifully lined arterial with beautiful architecture that is quieter than the adjacent Riverside Park (noisy because the highway lines it to the immediate west).\n\nIt\u2019s ALL of those things!",
#         "time": 1552955043
#       },
#       {
#         "author_name": "Karen Kasny",
#         "author_url": "https://www.google.com/maps/contrib/104446373519765950786/reviews",
#         "language": "en",
#         "profile_photo_url": "https://lh6.googleusercontent.com/-mSgYseFMcBQ/AAAAAAAAAAI/AAAAAAAAEL4/4DiZjMpf6pw/s128-c0x00000000-cc-rp-mo-ba5/photo.jpg",
#         "rating": 4,
#         "relative_time_description": "2 months ago",
#         "text": "This monument  is a hidden gem of the upper west side to a lesser known president.  The structure is grand.  The interior is a solemn and peaceful. There are restrooms and a gift shop across the street.  Columbia university is only a few blocks away.  Definitely worth a visit when in the neighborhood.",
#         "time": 1550615307
#       },
#       {
#         "author_name": "Nathaniel Loehrke",
#         "author_url": "https://www.google.com/maps/contrib/104360232934760135522/reviews",
#         "language": "en",
#         "profile_photo_url": "https://lh3.googleusercontent.com/-iQYEe4RG3nM/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rfxXGiUB_RhMLqRdmgvEmRH0ABv2w/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg",
#         "rating": 5,
#         "relative_time_description": "2 weeks ago",
#         "text": "A beautiful quiet space dedicated to a dedicated country man and husband.  Finding a peaceful place in Manhattan is not an easy endeavor - here is one.",
#         "time": 1556225292
#       },
#       {
#         "author_name": "Kate Estrada",
#         "author_url": "https://www.google.com/maps/contrib/100917360264016130962/reviews",
#         "language": "en",
#         "profile_photo_url": "https://lh6.googleusercontent.com/-xTKcyxhegoI/AAAAAAAAAAI/AAAAAAAAAAg/1MEhuhSFgl8/s128-c0x00000000-cc-rp-mo-ba2/photo.jpg",
#         "rating": 4,
#         "relative_time_description": "a week ago",
#         "text": "A national treasure. And it's in such a relaxed part of NYC, surrounded by Riverside Park, which overlooks the Hudson River. A must see.",
#         "time": 1556460546
#       },
#       {
#         "author_name": "Rudy Gonzales",
#         "author_url": "https://www.google.com/maps/contrib/101518791255484737000/reviews",
#         "language": "en",
#         "profile_photo_url": "https://lh4.googleusercontent.com/-i8w8FltVgoA/AAAAAAAAAAI/AAAAAAAABPY/IPmKssh9PzA/s128-c0x00000000-cc-rp-mo-ba3/photo.jpg",
#         "rating": 2,
#         "relative_time_description": "3 weeks ago",
#         "text": "The city has allowed this monument to deteriorate. Grafetti everywhere, trash everywhere. Not the way to honor a great man.",
#         "time": 1555363719
#       }
#     ],
#     "website": "http://www.nps.gov/gegr/index.htm"
#   },
#   "status": "OK"
# }

# %%
open_now = temp["result"]["opening_hours"]["open_now"]
open_time = temp["result"]["opening_hours"]["weekday_text"]
phone_number = temp["result"]["formatted_phone_number"]
price_level = temp["result"]["price_level"]
if price_level == 0:
    price = 'Free'
elif price_level == 1:
    price = 'Inexpensive'
elif price_level == 2:
    price = 'Moderate'
elif price_level == 3:
    price = 'Expensive'
elif price_level == 4:
    price = 'Very Expansive'
    
rating = temp["result"]["rating"]
typical_review = [temp["result"]["reviews"][i]["text"] for i in range(3)]
website = temp["result"]["website"]

res = [{"open_now":open_now},{"open_time":open_time},{"phone_number":phone}]
# Out:
# http://www.nps.gov/gegr/index.htm
